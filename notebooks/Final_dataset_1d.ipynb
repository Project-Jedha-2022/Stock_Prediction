# %%
import pandas as pd
import numpy as np

# %%
social = pd.read_csv('/content/ubisoft_reddit_sentiment_analysis.csv')
technical = pd.read_csv('/content/Dataset_2017_2022.csv')

# %%
social.info()
technical.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1624 entries, 0 to 1623
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   date                  1624 non-null   datetime64[ns]
#  1   title_vader_compound  1624 non-null   float64
#  2   title_roberta_neg     1624 non-null   float64
#  3   title_roberta_neu     1624 non-null   float64
#  4   title_roberta_pos     1624 non-null   float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 63.6 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1437 entries, 0 to 1436
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   date                 1437 non-null   datetime64[ns]
#  1   SMA_ratio            1437 non-null   float64
#  2   SMA_Volume_Ratio     1437 non-null   float64
#  3   Stochastic_15        1437 non-null   float64
# ...

# %%
social["date"] =  pd.to_datetime(social["date"], format="%Y-%m-%d")
technical["date"] =  pd.to_datetime(technical["date"], format="%d/%m/%Y")

# %%
social
# Out:
#            date  title_vader_compound  title_roberta_neg  title_roberta_neu  \
# 0    2017-01-01              0.484300           0.241092           0.644713
# 1    2017-01-02             -0.167350           0.777352           0.212674
# 2    2017-01-03             -0.158900           0.352967           0.593894
# 3    2017-01-04             -0.170000           0.455775           0.529359
# 4    2017-01-05              0.440400           0.090196           0.465504
# ...         ...                   ...                ...                ...
# 1619 2022-07-27              0.135070           0.314972           0.545255
# 1620 2022-07-28             -0.051575           0.359041           0.520645
# 1621 2022-07-29              0.038482           0.217296           0.714671
# 1622 2022-07-30              0.108950           0.309946           0.504471
# 1623 2022-07-31             -0.176375           0.333874           0.595047
#
#       title_roberta_pos
# 0              0.114195
# ...

# %%
technical
# Out:
#            date  SMA_ratio  SMA_Volume_Ratio  Stochastic_15  Stochastic_Ratio  \
# 0    2017-01-02   0.977920          0.492545      97.353507          1.120103
# 1    2017-01-03   0.980867          0.742189      75.999927          0.982504
# 2    2017-01-04   0.986854          0.853517      53.600042          0.811504
# 3    2017-01-05   0.999960          1.239421       3.183555          0.595832
# 4    2017-01-06   1.013771          1.492017       8.742321          0.412543
# ...         ...        ...               ...            ...               ...
# 1432 2022-08-04   0.973560          1.468748      63.784240          1.028058
# 1433 2022-08-05   0.961970          1.472961      60.960711          0.985775
# 1434 2022-08-08   0.951176          1.523725      59.388655          0.970349
# 1435 2022-08-09   0.937794          1.542949      47.510918          1.097616
# 1436 2022-08-10   0.929956          1.487341      50.480352          1.026554
#
# ...

# %%
dataset = technical.merge(social, left_on='date', right_on='date', how='inner')
dataset
# Out:
#            date  SMA_ratio  SMA_Volume_Ratio  Stochastic_15  Stochastic_Ratio  \
# 0    2017-01-02   0.977920          0.492545      97.353507          1.120103
# 1    2017-01-03   0.980867          0.742189      75.999927          0.982504
# 2    2017-01-04   0.986854          0.853517      53.600042          0.811504
# 3    2017-01-05   0.999960          1.239421       3.183555          0.595832
# 4    2017-01-06   1.013771          1.492017       8.742321          0.412543
# ...         ...        ...               ...            ...               ...
# 1136 2022-07-25   1.002685          1.209986      36.234424          1.274246
# 1137 2022-07-26   1.002241          1.184361      18.472426          1.045688
# 1138 2022-07-27   1.004621          1.135493      40.497689          0.901518
# 1139 2022-07-28   1.004128          1.092158      60.382491          0.848367
# 1140 2022-07-29   1.001406          1.063534      64.890999          0.853728
#
# ...

# %%
dataset.to_csv('dataset_social_technical_1d.csv', index=False)
